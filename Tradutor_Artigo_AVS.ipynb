# %% [markdown]
# <a href="https://colab.research.google.com/github/alecioADS/Projetos-DIO/blob/main/Tradutor_Artigo_AVS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install requests beautifulsoup4 openai langchain-openai

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_url(url):
    response = requests.get(url)

    if response.status_code == 200:
      soup = BeautifulSoup(response.text, 'html.parser')
      for script_or_style in soup(['script', 'style']):
        script_or_style.decompose()
      text = soup.get_text(separator= ' ')
      #limpar texto
      linhas = (line.strip() for line in text.splitlines())
      parts = (phrase.strip() for line in linhas for phrase in line.split("  "))
      text_limpo = '\n'.join(part for part in parts if part)

      return text_limpo

    else:
      print(f"Failed to fetch the URL. Status code: {response.status_code}")
      return None

    text = soup.get_text()
    return text

extract_text_from_url('https://dev.to/urzahmed/quantum-ai-introduction-a-better-future-159i')
# Out:
# "Quantum AI —Introduction - A better future? - DEV Community\nForem Feed\nFollow new Subforems to improve your feed\nDEV Community\nFollow\nA space to discuss and keep up software development and manage your software career\nFuture\nFollow\nNews and discussion of science and technology such as AI, VR, cryptocurrency, quantum computing, and more.\nOpen Forem\nFollow\nA general discussion space for the Forem community. If it doesn't have a home elsewhere, it belongs here\nGamers Forem\nFollow\nAn inclusive community for gaming enthusiasts\nMusic Forem\nFollow\nFrom composing and gigging to gear, hot music takes, and everything in between.\nVibe Coding Forem\nFollow\nDiscussing AI software development, and showing off what we're building.\nPopcorn Movies and TV\nFollow\nMovie and TV enthusiasm, criticism and everything in-between.\nDUMB DEV Community\nFollow\nMemes and software development shitposting\nDesign Community\nFollow\nWeb design, graphic design and everything in-between\nSecur
# ...

# %%
from langchain_openai.chat_models.azure import AzureChatOpenAI

client = AzureChatOpenAI(
    azure_endpoint= "https://oai-bootcamp-avs.openai.azure.com/",
    api_key= "7iZzwjxFopcJLTJsDPvu3NKmnXZ4qp2ulL9sxNB5mKcxhMd1QHkQJQQJ99CAACHYHv6XJ3w3AAABACOGOwHz",
    api_version= "2024-12-01-preview",
    deployment_name= "gpt-4.1",
    max_retries=0
)

def translate_article(text, lang):
  messages = [
      ("system" , "Você atua como tradutor de textos"),
      ("user" , f"Traduza o {text} para o idioma {lang} e responda em markdown")
  ]

  response = client.invoke(messages)
  print(response.content)
  return response.content

translate_article("Quantum Computing Basics", "portugues")
# Out:
# Claro! Segue uma tradução para o português de "Quantum Computing Basics" em markdown:
#
# ```markdown
# # Fundamentos da Computação Quântica
#
# ## Introdução
#
# A computação quântica é uma área da ciência da computação que utiliza os princípios da mecânica quântica para processar informações. Ao contrário dos computadores clássicos, que usam bits para representar dados como 0 ou 1, os computadores quânticos usam qubits, que podem representar ambos os estados simultaneamente, graças ao fenômeno da superposição.
#
# ## Princípios Fundamentais
#
# - **Qubits**: Unidade básica de informação em um computador quântico. Um qubit pode estar em uma superposição de 0 e 1.
# - **Superposição**: Um qubit pode existir em múltiplos estados ao mesmo tempo, o que permite aos computadores quânticos realizar múltiplos cálculos simultaneamente.
# ...

# %%
url = 'https://dev.to/urzahmed/quantum-ai-introduction-a-better-future-159i'
text = extract_text_from_url(url)
article = translate_article(text, "pt-br")
print(article)
# Out:
# Claro! Segue abaixo a tradução do artigo "Quantum AI —Introduction - A better future?" para o português (pt-br), em formato Markdown. Traduzi apenas o conteúdo relevante do artigo em si, omitindo menus, botões e informações automáticas do site, conforme solicitado.
#
# ---
#
# # Quantum AI — Introdução – Um futuro melhor?
#
# > Quantum AI, abreviação de Inteligência Artificial Quântica, representa a fusão da computação quântica com a inteligência artificial, oferecendo possibilidades empolgantes para resolver problemas complexos.
#
# ---
#
# ## Conceitos principais
#
# ### 1. Noções básicas de Computação Quântica
#
# - **Bits Quânticos (Qubits):** A unidade fundamental na computação quântica, capaz de representar múltiplos estados simultaneamente por meio da superposição.
# - **Emaranhamento:** O fenômeno em que qubits se tornam correlacionados, permitindo a criação de sistemas interconectados.
# ...
